# %%
import glob
import csv
import os
import pandas as pd

# %%
for files in glob.glob('C:\\Users\\Hi\Desktop\\final_exam\\Final Exam\\Day\\*.csv'):
    f = open(files, 'r')
    name = os.path.basename(f.name).replace(".csv","")
    data = pd.read_csv(f)
    lis = []
    for each in range(0, len(data)-1):
        row2 = data.iloc[each]
        row1 = data.iloc[each+1]
        gl = (row2["Close"] + row1["Close"]) / row1["Close"]
        lis.append(gl)
        lis.append()
    lis.insert(0,0)
    data.loc[:,'gainORloss'] = lis
    data.to_csv(r'C:\\Users\\Hi\\Desktop\\final_exam\\Final Exam\Day\\'+name+'.csv')
    f.close()
print(lis)
# Out:
# [0, 1.9975878973784946, 1.997593786338463, 1.999717051074489, 1.9960535727718207, 2.0056696524874704, 2.000141791889116, 1.994922411990905, 1.9841754721796852, 1.9987523082802847, 1.990116664107527, 1.9826004718451644, 1.9963713884493273, 1.9912082589583058, 1.9950954137037267, 2.0005305039647086, 2.003727356081176, 2.000799427146268, 1.9972100570164761, 1.9955031874685467, 2.0053184683595062, 1.9966869864390007, 2.000795716159265, 2.0060040696199093, 1.989438904290429, 1.9913623352251102, 1.9887423005789633, 1.99446660654313, 2.004913965992138, 2.0038946255211556, 2.0071913700107986, 1.999869329320678, 1.9994773160783654, 2.015256063223245, 1.9939346120218675, 2.019354757544227, 1.9990600376116552, 1.9991949818756873, 1.9989277308815476, 2.003902058665232, 2.000942760942761, 2.00759937555708, 2.003540814381043, 1.9937745431556981, 2.0055796949273397, 1.9939132016772623, 2.007632506161953, 2.0005454929620754, 1.997008824051306, 1.9994565429790212, 2.002315418205269, 2.010737871843858, 2.0055371125563983, 2.0071099258144462, 1.9698486204684778, 2.1048699849157457, 2.0303217018574466, 1.9919084122137405, 1.9992371777618376, 2.000152609091355, 2.000305311369291, 1.9928776933740777, 2.0093300860812215, 2.0010717960824316, 2.0083372089703815, 2.0071528380392736, 1.9918260636536744, 1.9929554827126115, 1.9977082657467502, 2.0178848203164157, 2.009577704656582, 1.9891287465309633, 2.0051514363144376, 2.0054936274602673, 2.0017295755260873, 1.9925093011076995, 2.002346347567652, 2.001880567279728, 1.9962528963503716, 2.010252381380051, 1.997796679291837, 2.010656943067551, 1.9936778726094515, 2.0086083213773316, 2.008034709946971, 1.9958393024215295, 1.999840032, 1.9998400575856683, 2.003692983360517, 1.9982368969103526, 1.9972825767697797, 2.0053029246344205, 2.016497859906928, 1.9954471707317072, 1.9841574336963534, 1.9796206461887342, 1.988685740329467, 2.0017077005615462, 2.003427356179238, 2.012141343807674, 2.0082670267641642, 1.9925832885053385, 1.9981098913810083, 1.9949851278015183, 2.020143917188552, 1.9839546798804468, 1.9778495315228573, 2.0021581469635508, 1.9926550112518748, 2.0046117599717865, 1.9951047883537654, 2.007707722782131, 2.00092586023533, 2.0068354043730587, 1.9903077384615384, 2.007751937984496, 2.0057695776907645, 2.0053299262371858, 1.969600243660127, 2.0134011556808735, 2.0135830594730804, 1.997352880763736, 1.9925812052201486, 2.012519483176229, 1.9998435612580192, 2.0072497871197825, 1.986627320374042, 1.9956649943127414, 2.001240024763912, 1.9921563361499386, 1.987545579437763, 2.0016734062829724, 2.007201976487834, 1.9905890250723597, 1.9918699033986724, 2.0089624180780064, 2.002741812559275, 2.002443182239828, 2.000152642021107, 2.00630095282004, 1.979969850000908, 1.9856018857532187, 1.993218354910265, 1.9890638673355536, 1.9785958910218067, 1.9985751211171274, 1.9793468613258802, 2.0022378181818183, 1.9994408582689287, 1.9984647453324564, 1.9990239961095373, 1.9917035536504426, 2.0073826297899062, 2.0016743826335817, 1.9865106128971612, 1.983085250796069, 2.017906391677862, 2.009174256069662, 1.9972276545221466, 2.0008323667915544, 1.9951677757835156, 2.0162761757938616, 1.9980393923518056, 2.0094713884498554, 2.003688918685205, 2.0039886896291463, 1.9971590199670732, 2.001280102440054, 2.010636739974127, 1.9897567080700427, 2.0, 2.0097687112517066, 2.0100116514803146, 1.9824660874564193, 2.001713594198395, 1.9846737351796795, 1.9977553871738971, 1.997620741677568, 1.9984628143785026, 2.0236016865340187, 1.9843706977346112, 2.017041314133143, 2.0001432540819253, 1.9926073922438092, 2.0058629486629482, 2.007636858569543, 2.0508782699745867, 1.992634931499097, 1.9961071717905796, 2.0427790456153456, 2.0003124160598533, 1.97980108583936, 1.9955819469162395, 2.007057364222154, 1.997856705450092, 1.9978613045808324, 2.019784965889236, 2.004066979508838, 2.0093148089674773, 1.9806472197335327, 1.9871617912272654, 2.02234375, 2.016679888535665, 2.00832934486625, 1.9980815507287217, 1.9753625748649262, 1.9 ...

# %%
for files in glob.glob('C:\\Users\\Hi\Desktop\\final_exam\\Final Exam\\Month\\*.csv'):
    f=open(files, 'r')
    name = os.path.basename(f.name).replace(".csv","")
    data = pd.read_csv(f)
    lis = []
    for each in range(0, len(data)-1):
        row2 = data.iloc[each]
        row1 = data.iloc[each+1]
        gl = (row2["Close"] + row1["Close"]) / row1["Close"]
        lis.append(gl)
    lis.insert(0,0)
    data.loc[:,'gainORloss'] = lis
    data.to_csv(r'C:\\Users\\Hi\Desktop\\final_exam\\Final Exam\\Month\\'+name+'.csv')
    f.close()

# %%
for files in glob.glob('C:\\Users\\Hi\Desktop\\final_exam\\Final Exam\\Week\\*.csv'):
    f=open(files, 'r')
    name = os.path.basename(f.name).replace(".csv","")
    data = pd.read_csv(f)
    lis = []
    for each in range(0, len(data)-1):
        row2 = data.iloc[each]
        row1 = data.iloc[each+1]
        gl = (row2["Close"] + row1["Close"]) / row1["Close"]
        lis.append(gl)
    lis.insert(0,0)
    data.loc[:,'gainORloss'] = lis
    data.to_csv(r'C:\\Users\\Hi\Desktop\\final_exam\\Final Exam\\Week\\'+name+'.csv')
    f.close()
